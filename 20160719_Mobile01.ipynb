# %% [markdown]
# ## Mobile01

# %%
from __future__ import print_function
import sys
import requests as rs
from bs4 import BeautifulSoup as bs
from datetime import date,datetime
import json
from splinter import Browser
import time

# %%
f= open('e:/jupyter/TRAVEL/mobel_3_4.txt','w')
base_url='http://www.mobile01.com/waypointlist.php?list=1&c=1&s=desc&pid=2&p={}'
for page in range(3,4):
    res=rs.get(base_url.format(page))
    soup=bs(res.text,'html5lib')
    for t in soup.select('tbody .rb16'):
        url='http://www.mobile01.com/'+t['href']
        #print(url)
        res_url=rs.get(url)       
        soup=bs(res_url.text,'html5lib')       
        for content in soup.select('main .single-post-content'):
            time.sleep(30)  
            #print  (content.text)
            f.write(content.text.encode('utf-8'))
f.close()

# %% [markdown]
# ## Mobile01景點爬蟲

# %%
f= open('e:/jupyter/TRAVEL/mobel_1_18.txt','w')
base_url='http://www.mobile01.com/waypointlist.php?list=1&c=1&s=desc&pid=2&p={}'
for page in range(1,18):
    res=rs.get(base_url.format(page))
    soup=bs(res.text,'html5lib')
    for t in soup.select('tbody .rb16'):
        url='http://www.mobile01.com/'+t['href']
        #print(url)
        res_url=rs.get(url)       
        soup=bs(res_url.text,'html5lib')       
        for content in soup.select('main .single-post-content'):
            time.sleep(30)
            #print  (content.text)
            f.write(content.text.encode('utf-8'))
f.close()

# %% [markdown]
# ## Jieba

# %%
import jieba
seg_list = jieba.cut("整個228黃金連假就帶著PanasonicGF1散步到永靜公園", cut_all=True)
print("Full Mode: " + "/ ".join(seg_list))
seg_list = jieba.cut("整個228黃金連假就帶著PanasonicGF1散步到永靜公園", cut_all=False)
print("Default Mode: " + "/ ".join(seg_list)) 
seg_list = jieba.cut("整個228黃金連假就帶著PanasonicGF1散步到永靜公園", cut_all=False)
print(", ".join(seg_list))
# ，雨滴滴答答的下，Lil' Mike既沒有安排計劃去遠遊，外頭濕冷更沒有心情四處走走，
#                          頂多和家人外出吃晚飯。最主要原因還是因為鼻子剛
#                          開完刀，想在家裡多休養，看著電視上到處都是塞車賞 櫻人潮，Lil' Mike才想起好像沒去賞過櫻，打了電話問三芝朋友，
#                          卻說元天宮櫻花還沒完全開，而武陵又太塞太遠，
#                          此時老母突然說旁邊公園的櫻花早開了。甚麼??? 旁邊公園有種櫻花，Lil' Mi
#                          ke完全不知情，先納入口袋行程再說。今天很幸運的陽光普照，吃完蘇記玉米排骨湯
#                          後，

# %%
import jieba

seg_list = jieba.cut("我来到北京清华大学", cut_all=True)
print("Full Mode: " + "/ ".join(seg_list))  # 全模式

seg_list = jieba.cut("我来到北京清华大学", cut_all=False)
print("Default Mode: " + "/ ".join(seg_list))  # 精确模式

seg_list = jieba.cut("他来到了网易杭研大厦")  # 默认是精确模式
print(", ".join(seg_list))

seg_list = jieba.cut_for_search("小明硕士毕业于中国科学院计算所，后在日本京都大学深造")  # 搜索引擎模式
print(", ".join(seg_list))

# %%
#encoding=utf-8
import jieba

sentence = "整個228黃金連假，雨滴滴答答的下，Lil' Mike既/t
沒有安排計劃去遠遊，外頭濕冷更沒有心情四處走走，頂多和家人外出吃晚飯。最主要原因還是因為鼻子剛開完刀，想在家裡多休養，看著電視上到處都是塞車賞櫻人潮，Lil' Mike才想起好像沒去賞過櫻，
打了電話問三芝朋友，卻說元天宮櫻花還沒完全開，而武陵又太塞太遠，此時老母突然說旁邊公園的櫻花早開了。甚麼??? 旁邊公園有種櫻花，Lil' Mike完全不知情，先納入口袋行程再說。今天很幸運的陽光普照，
吃完蘇記玉米排骨湯後，就帶著Panasonic GF1散步到"永靜公園"。"
print ("Input：" ,sentence)
words = jieba.cut(sentence, cut_all=False)
print ("Output 精確模式 Full Mode：")
# for word in words:
#     print word

# sentence = "独立音乐需要大家一起来推广，欢迎加入我们的行列！"
# print "Input：", sentence
# words = jieba.cut(sentence, cut_all=False)
# print "Output 精確模式 Full Mode："
# for word in words:
#     print word

# %% [markdown]
# ## Mobile01景點一覽爬蟲

# %%
f= open('e:/jupyter/TRAVEL/mobel_81_300_includefood.txt','w')
base_url='http://www.mobile01.com/waypointlist.php?list=1&c=0&s=desc&pid=2&p={}'
#25755網頁抓不到
for page in range(81,300):
    res=rs.get(base_url.format(page))
    soup=bs(res.text,'html5lib')
    for t in soup.select('tbody .rb16'):
        url='http://www.mobile01.com/'+t['href']
        print(url)
        res_url=rs.get(url)       
        soup=bs(res_url.text,'html5lib')       
        for content in soup.select('main .single-post-content'):
            time.sleep(10)
            #print  (content.text)
            print(datetime.now().strftime('%Y%m%d')+datetime.now().strftime('%H%M%S'))
            f.write(content.text.encode('utf-8'))
f.close()
# Out:
# http://www.mobile01.com/waypointdetail.php?id=24346
# 20160723141602
# http://www.mobile01.com/waypointdetail.php?id=24344
# 20160723141612
# http://www.mobile01.com/waypointdetail.php?id=24343
# 20160723141622
# http://www.mobile01.com/waypointdetail.php?id=24340
# 20160723141632
# http://www.mobile01.com/waypointdetail.php?id=24339
# 20160723141643
# http://www.mobile01.com/waypointdetail.php?id=24338
# 20160723141653
# http://www.mobile01.com/waypointdetail.php?id=24337
# 20160723141703
# http://www.mobile01.com/waypointdetail.php?id=24336
# 20160723141713
# http://www.mobile01.com/waypointdetail.php?id=24335
# 20160723141723
# http://www.mobile01.com/waypointdetail.php?id=24334
# 20160723141734
# http://www.mobile01.com/waypointdetail.php?id=24333
# 20160723141744
# http://www.mobile01.com/waypointdetail.php?id=24329
# 20160723141755
# http://www.mobile01.com/waypointdetail.php?id=24319
# 20160723141805
# http://www.mobile01.com/waypointdetail.php?id=24318
# 20160723141815
# ...

# %%
s = 'hello world'
# print(len(s))
# print(s[0])
print(s[-1])
print(s[1:4]+'yoyo')
print(s[:-3]+'yoyo')
print(s[-3:])
# print(s)
# print(s + 'yoyo')
# print(s.__add__('yoyo'))
#print(s[::2])
#print(range(10)[::3]) # gets every third item of the sequence sliced

# %% [markdown]
# ## selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
from bs4 import BeautifulSoup 

driver = webdriver.Chrome()


driver.get("http://www.agoda.com/zh-tw/city/taipei-tw.html?asq=jGXBHFvRg5Z51Emf%2fbXG4w%3d%3d&cid=1732641&tag=41460a09-3e65-d173-1233-629e2428d88e")
driver.find_element_by_id("search-submit").click()
for i in range(1,5):
    
    soup = BeautifulSoup(driver.page_source,'html5lib')
    for hotel in soup.select('div.hotel-info'):
        print (hotel.select('.hotel-name')[0].text)
    driver.find_element_by_id("paginationNext").click()


driver.close()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re


driver = webdriver.Chrome()
driver.implicitly_wait(3)

driver.get("https://www.tripadvisor.com.tw/Attraction_Review-g293913-d2019764-Reviews-Elephant_Mountain_aka_Nangang_District_Hiking_Trail-Taipei.html")
driver.find_element_by_class_name("a.nav.next.rndBtn.ui_button.primary.taLnk").click()
for i in range(1,5):
    driver.implicitly_wait(300)
    soup = bs(driver.page_source,)
    
    for title in soup.select('heading_name.with_alt_title'):
        
        
        
        for discuss in soup.select('.partial_entry'):
            
            print(title.text+discuss.text)
            
            
   


            driver.close()

# %%
name = "Nate"
print("nice to meet you", name)
print("nice to meet you {}".format(name)) # 建議的寫法
print("nice to meet you %s"%name)
print("nice to meet you : {0}, I'm {1} {1} {1} {1}".format("jully","nate"))
print("nice to meet you : %s, I'm %s %s %s %s"%("jully", "nate","nate","nate","nate"))
print("The results are %.02f and %d" % (3.14159, 5))

# %%
from __future__ import print_function
import sys
import requests
from bs4 import BeautifulSoup as bs
from datetime import date,datetime
import json
from splinter import Browser
import time
